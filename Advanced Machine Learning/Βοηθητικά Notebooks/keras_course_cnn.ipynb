# %% [markdown]
# <table>
# <td>
# <img src="https://people.iee.ihu.gr/~kdiamant/images/kdiamantaras2.jpg" alt="Kostas Diamantaras" height="100"/>
# </td>
# <td>
# <p>Konstantinos Diamantaras</p>
# <p>Department of Information and Electronic Engineering</p>
# <p>International Hellenic University</p>
# <p>Greece</p>
# </td>
# <td>
# <img src="https://people.iee.ihu.gr/~kdiamant/images/International_Hellenic_University_logo.jpg" alt="Kostas Diamantaras" height="100"/>
# </td>
# </table>
#
# # Implement a simple Convolutional NN model
# <ul>
# <li> Use layers: <code>Input</code>, <code>Dense</code>, <code>Flatten</code>, <code>Conv2D</code>, <code>Activation</code>, <code>BatchNormalization</code>, <code>AveragePooling2D</code></li>
# <li> Build and train the model</li>
# <li> Predict test patterns</li>
# <li> Dataset: <a href="https://www.cs.toronto.edu/~kriz/cifar.html">CIFAR10</a></li>
# </ul>

# %% [markdown]
# #### **Read CIFAR10 image dataset**

# %%
import tensorflow as tf
from tensorflow.keras.datasets import cifar10

(xo_train, t_train), (xo_test, t_test) = cifar10.load_data()

print('Train image data {}'.format(xo_train.shape))
print('Test image data {}'.format(xo_test.shape))
print('Train labels {}'.format(t_train.shape))
print('Test labels {}'.format(t_test.shape))
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 6s 0us/step
# Train image data (50000, 32, 32, 3)
# Test image data (10000, 32, 32, 3)
# Train labels (50000, 1)
# Test labels (10000, 1)

# %% [markdown]
# Some example images with labels

# %%
import matplotlib.pyplot as plt

class_names = ['airplane','automobile','bird','cat','deer','dog','frog','horse','ship','truck']
plt.figure(figsize=(12,9))
plt.subplots_adjust(wspace=0.4, hspace=0.4)
for i in range(16):
    axes = plt.subplot(4,4,i+1)
    axes.set_title(class_names[t_train[i,0]], fontdict={'fontsize':14, 'color':'yellow'})
    plt.imshow(xo_train[i])

# %% [markdown]
# Do some preprocessing of the data.
# `input_shape` = [32,32,3] is the shape of one input sample, ie. 3 images (the Red/Green/Blue components) each one with size 32x32.
# Also normalize the images dividing by 255 (so all values are between -1, 1) and then subtract the mean pixel value

# %%
import numpy as np

# number of classes
num_classes = 10

# Input image dimensions.
input_shape = xo_train.shape[1:]    # (32,32,3)

# Normalize data.
x_train = xo_train.astype('float32') / 255.0
x_test = xo_test.astype('float32') / 255.0

# Subtract pixel mean
x_train_mean = np.mean(x_train, axis=0)
x_train -= x_train_mean
x_test -= x_train_mean

# %% [markdown]
# #### Build a Convolutional neural network (CNN)

# %%
from tensorflow.keras.layers import Input

x_in = Input(shape=input_shape)
# Out:
# <tf.Tensor 'input_1:0' shape=(None, 32, 32, 3) dtype=float32>

# %% [markdown]
# #### Conv2D layer (see [Convolutional layers](https://keras.io/layers/convolutional/))
# The Conv2D layer implements a 2d Convolutional layer.
#
# <table><tr>
# <td>
# <img src="https://people.iee.ihu.gr/~kdiamant/images/Convolution2D.png" alt="Dense layer" width="300"/>
# </td>
# <td width="250">
# <p>$\mathbf{y}_i = f( \sum_j k_{ij} * \mathbf{x}_j + b_i )$</p>
# <p>$\mathbf{x}_j$: $j$-th output image</p>
# <p>$\mathbf{y}_i$: $i$-th output image</p>
# <p>$*$: convolution operation</p>
# <p>$k_i$: $i$-th kernel filter</p>
# <p>$b_i$: $i$-th bias</p>
# <p>$f$: activation function</p>
# </td></tr>
# </table>
#
# It assumes that the input `x` is a 4-d tensor with shape `(None,height,width,num_channels)`.
# As usual, the first dimension is unspecified because it corresponds to the unknown `batch_size`.
# You may specify the inputs shape using the parameter `input_shape=(height,width,num_channels)`
# but you can skip this parameter if you specify the input tensor `x` in which case the input shape will be infered from it.
# Mandatory parameters:
# * `filters` = number of kernel filters to be used to produce output images
# * `kernel_size` = the size of the receptive field of each kernel filter. It is either an integer n, in which case the kernel size is assumed to be n$\times$n, or it is a tuple (n1,n2)
#
# Some important optional parameters:
# * `padding` = one of `"valid"` or `"same"`.
# The value `"valid"` (default) means that no padding is done to the input images so the output images will have size (`height-kernel_size+1`)$\times$(`width-kernel_size+1`).
# The value `"same"` means that the input images are padded with the necessary zeros so that the output images will have the same size as the inputs, ie. `height`$\times$`width`.
# * `strides` = the stride step along image directions x and y. It can be an integer s, in which case the strides are assumed to be s in both direction, or it is a tuple (s1,s2). The default value is 1.
# * `activation` = the activation function of the neurons. The default activation is linear.
# For example:

# %%
from tensorflow.keras.layers import Conv2D, Dense, Reshape, Flatten

#First Convolutional layer
x = Conv2D(filters=16, kernel_size=3,
           activation='relu',
           padding="same")(x_in)
print(x.shape)  # Ouput x has 16 images of same shape as the input, ie 32x32
# Out:
# (None, 32, 32, 16)

# %% [markdown]
# Add more layers to the network

# %%
#Second Convolutional layer
x = Conv2D(filters=20, kernel_size=3,
           activation='relu',
           padding="same")(x)
#Third Convolutional layer
x = Conv2D(filters=32, kernel_size=3,
           activation='relu',
           padding="same")(x)
# Flatten the data
x = Flatten()(x)
print(x.shape)
# Output fully connected layer with softmax activation
out = Dense(num_classes, activation='softmax')(x)
# Out:
# (None, 32768)

# %% [markdown]
# #### Build the keras [Model](https://keras.io/models/model/)

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.losses import sparse_categorical_crossentropy
from tensorflow.keras.optimizers import Adam

model = Model(inputs=x_in, outputs=out)
lr = 1e-3   # Learning rate
model.compile(loss='sparse_categorical_crossentropy',
              optimizer=Adam(lr=lr),
              metrics=['accuracy'])
model.summary()
# Out:
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 32, 32, 3)]       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 32, 32, 16)        448
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 32, 20)        2900
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 32, 32, 32)        5792
# _________________________________________________________________
# flatten (Flatten)            (None, 32768)             0
# _________________________________________________________________
# dense (Dense)                (None, 10)                327690
# =================================================================
# Total params: 336,830
# Trainable params: 336,830
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #### Train the model

# %%
max_epochs = 30
batch_size = 32

history = model.fit(x=x_train, y=t_train,
                    validation_data=(x_test,t_test),
                    batch_size=batch_size,
                    epochs=max_epochs,
                    verbose=1)
# Out:
# Epoch 1/30
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.3491 - accuracy: 0.5220 - val_loss: 1.1173 - val_accuracy: 0.6094
# Epoch 2/30
# 1563/1563 [==============================] - 6s 4ms/step - loss: 0.9606 - accuracy: 0.6659 - val_loss: 1.0018 - val_accuracy: 0.6539
# Epoch 3/30
# 1563/1563 [==============================] - 5s 4ms/step - loss: 0.7765 - accuracy: 0.7320 - val_loss: 0.9917 - val_accuracy: 0.6629
# Epoch 4/30
# 1563/1563 [==============================] - 5s 4ms/step - loss: 0.6119 - accuracy: 0.7892 - val_loss: 1.0280 - val_accuracy: 0.6613
# Epoch 5/30
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.4617 - accuracy: 0.8422 - val_loss: 1.1826 - val_accuracy: 0.6490
# Epoch 6/30
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.3334 - accuracy: 0.8852 - val_loss: 1.4264 - val_accuracy: 0.6261
# Epoch 7/30
# 1563/1563 [==============================] - 5s 4ms/step - loss: 0.2239 - accuracy: 0.9232 - val_loss: 1.6932 - val_accuracy: 0.6294
# Epoch 8/30
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.1599 - accuracy: 0.9448 - val_loss: 1.9506 - val_accuracy: 0.6250
# Epoch 9/30
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.1224 - accuracy: 0.9580 - val_loss: 2.3388 - val_accuracy: 0.6138
# Epoch 10/30
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.1057 - accuracy: 0.9623 - val_loss: 2.3970 - val_accuracy: 0.6271
# Epoch 11/30
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.0904 - accuracy: 0.9685 - val_loss: 2.6444 - val_accuracy: 0.6137
# Epoch 12/30
# 1563/1563 [==============================] - 5s 4ms/step - loss: 0.0802 - accuracy: 0.9715 - val_loss: 2.8850 - val_accuracy: 0.6181
# Epoch 13/30
# 1563/1563 [==============================] - 5s 4ms/step - loss: 0.0733 - accuracy: 0.9751 - val_loss: 2.9298 - val_accuracy: 0.6097
# Epoch 14/30
# 1563/1563 [==============================] - 5s 4ms/step - loss: 0.0697 - accuracy: 0.9754 - val_loss: 3.2612 - val_accuracy: 0.6077
# Epoch 15/30
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.0698 - accuracy: 0.9762 - val_loss: 3.2698 - val_accuracy: 0.6132
# Epoch 16/30
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.0638 - accuracy: 0.9785 - val_loss: 3.4467 - val_accuracy: 0.6149
# Epoch 17/30
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.0610 - accuracy: 0.9797 - val_loss: 3.6265 - val_accuracy: 0.6092
# Epoch 18/30
# 1563/1563 [==============================] - 5s 4ms/step - loss: 0.0557 - accuracy: 0.9805 - val_loss: 3.7029 - val_accuracy: 0.6116
# Epoch 19/30
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.0598 - accuracy: 0.9800 - val_loss: 3.8580 - val_accuracy: 0.6091
# Epoch 20/30
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.0531 - accuracy: 0.9818 - val_loss: 3.9359 - val_accuracy: 0.6051
# Epoch 21/30
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.0557 - accuracy: 0.9818 - val_loss: 4.1166 - val_accuracy: 0.6032
# Epoch 22/30
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.0534 - accuracy: 0.9825 - val_loss: 4.2771 - val_accuracy: 0.6048
# Epoch 23/30
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.0496 - accuracy: 0.9837 - val_loss: 4.5709 - val_accuracy: 0.5968
# Epoch 24/30
# 1563/1563 [==============================] - 6s 4ms/step - loss: 0.0452 - accuracy: 0.9857 - val_loss: 4.6109 - val_accuracy: 0.6121
# Epoch 25/30
# 1563/1563 [==============================] - 6s 4ms/step - loss: 0.0503 - accuracy: 0.9834 - val_loss: 4.6039 - val_accuracy: 0.6043
# Epoch 26/30
# 1563/1563 [==============================] - 6s 4ms/step - loss: 0.0536 - accuracy: 0.9829 - val_loss: 4.5293 - val_accuracy: 0.6095
# Epoch 27/30
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.0481 - accuracy: 0.9835 - val_loss: 4.7897 - val_accuracy: 0.5982
# Epoch 28/30
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.0488 - accuracy: 0.9843 - val_loss: 4.7331 - val_accuracy: 0.5993
# Epoch 29/30
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.0437 - accuracy: 0.9859 - val_loss: 4.9150 - val_accuracy: 0.6011
# Epoch 30/30
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.0510 - accuracy: 0.9840 - val_loss: 5.0028 - val_accuracy: 0.6029

# %% [markdown]
# #### Plot the training and testing behavior

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(10,8))
fig.set_facecolor('lightgray')
plt.plot(history.history['accuracy'], 'b')
plt.plot(history.history['val_accuracy'], 'r')
plt.legend(['train acc', 'test acc'], fontsize=14)
ax.text(15, 0.9, 'Large\nOverfitting', fontsize=16,
        verticalalignment='top', bbox=dict(boxstyle='round', facecolor='wheat', alpha=0.5))
plt.xlabel('Epochs')
plt.grid(b=True)

# %% [markdown]
# #### A better model
# Use some additional layer types:
# * `BatchNormalization()` (see [Normalization layers](https://keras.io/layers/normalization/)):
# applies a transformation to the input batch that maintains the mean activation close to 0 and the activation standard deviation close to 1.
# * `Activation(f)` (see [Core layers](https://keras.io/layers/core/)):
# Applies the activation function `f` to the input tensor
# * `AveragePooling2D(pool_size)` (see [Pooling layers](https://keras.io/layers/pooling/)):
# Applies the transformation
# $y_{ij} = \frac{1}{p^2}\sum_{a=0}^{p-1} \sum_{b=0}^{p-1} x_{i+a,j+b}$
# to the input image $x_{ij}$ ($p$ is the `pool_size`)
# * `Dropout(fraction)`: (see [Core layers](https://keras.io/layers/core/)):
# Randomly sets a `fraction` of input units to 0 at each update during training time, which helps prevent overfitting

# %%
from tensorflow.keras.layers import BatchNormalization, Activation, AveragePooling2D, Dropout

def cnn_2(input_shape):
    x_in = Input(shape=input_shape)
    x = Conv2D(filters=16, kernel_size=3, padding="same")(x_in)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Dropout(rate=0.3)(x)
    x = Conv2D(filters=20, kernel_size=3, padding="same")(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Conv2D(filters=32, kernel_size=3, padding="same")(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    print(x.shape)
    x = AveragePooling2D(pool_size=4)(x)
    print(x.shape)
    x = Flatten()(x)
    out = Dense(num_classes, activation='softmax')(x)
    model = Model(inputs=x_in, outputs=out)
    return model

# %%
model2 = cnn_2(input_shape)
lr = 1e-3   # Learning rate
model2.compile(loss='sparse_categorical_crossentropy',
               optimizer=Adam(lr=lr),
               metrics=['accuracy'])
model2.summary()
# Out:
# (None, 32, 32, 32)
# (None, 8, 8, 32)
# Model: "functional_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 32, 32, 3)]       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 32, 32, 16)        448
# _________________________________________________________________
# batch_normalization (BatchNo (None, 32, 32, 16)        64
# _________________________________________________________________
# activation (Activation)      (None, 32, 32, 16)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 32, 32, 16)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 32, 32, 20)        2900
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 32, 32, 20)        80
# _________________________________________________________________
# activation_1 (Activation)    (None, 32, 32, 20)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 32, 32, 32)        5792
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 32, 32, 32)        128
# _________________________________________________________________
# activation_2 (Activation)    (None, 32, 32, 32)        0
# _________________________________________________________________
# average_pooling2d (AveragePo (None, 8, 8, 32)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                20490
# =================================================================
# Total params: 29,902
# Trainable params: 29,766
# Non-trainable params: 136
# _________________________________________________________________

# %%
max_epochs = 30
batch_size = 32

history2 = model2.fit(x=x_train, y=t_train,
                      validation_data=(x_test,t_test),
                      batch_size=batch_size,
                      epochs=max_epochs,
                      verbose=1)
# Out:
# Epoch 1/30
# 1563/1563 [==============================] - 7s 4ms/step - loss: 1.3689 - accuracy: 0.5111 - val_loss: 1.3481 - val_accuracy: 0.5367
# Epoch 2/30
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.0370 - accuracy: 0.6365 - val_loss: 0.9537 - val_accuracy: 0.6668
# Epoch 3/30
# 1563/1563 [==============================] - 7s 4ms/step - loss: 0.9200 - accuracy: 0.6788 - val_loss: 0.9658 - val_accuracy: 0.6700
# Epoch 4/30
# 1563/1563 [==============================] - 7s 4ms/step - loss: 0.8602 - accuracy: 0.7021 - val_loss: 0.9136 - val_accuracy: 0.6855
# Epoch 5/30
# 1563/1563 [==============================] - 6s 4ms/step - loss: 0.8169 - accuracy: 0.7160 - val_loss: 0.9068 - val_accuracy: 0.6911
# Epoch 6/30
# 1563/1563 [==============================] - 6s 4ms/step - loss: 0.7812 - accuracy: 0.7298 - val_loss: 0.8629 - val_accuracy: 0.7001
# Epoch 7/30
# 1563/1563 [==============================] - 6s 4ms/step - loss: 0.7606 - accuracy: 0.7377 - val_loss: 0.8706 - val_accuracy: 0.7003
# Epoch 8/30
# 1563/1563 [==============================] - 6s 4ms/step - loss: 0.7408 - accuracy: 0.7440 - val_loss: 0.8253 - val_accuracy: 0.7180
# Epoch 9/30
# 1563/1563 [==============================] - 6s 4ms/step - loss: 0.7208 - accuracy: 0.7521 - val_loss: 0.9004 - val_accuracy: 0.6991
# Epoch 10/30
# 1563/1563 [==============================] - 6s 4ms/step - loss: 0.7038 - accuracy: 0.7574 - val_loss: 0.8103 - val_accuracy: 0.7247
# Epoch 11/30
# 1563/1563 [==============================] - 6s 4ms/step - loss: 0.6905 - accuracy: 0.7609 - val_loss: 0.8593 - val_accuracy: 0.7104
# Epoch 12/30
# 1563/1563 [==============================] - 6s 4ms/step - loss: 0.6815 - accuracy: 0.7644 - val_loss: 0.9012 - val_accuracy: 0.7007
# Epoch 13/30
# 1563/1563 [==============================] - 6s 4ms/step - loss: 0.6654 - accuracy: 0.7687 - val_loss: 0.8210 - val_accuracy: 0.7222
# Epoch 14/30
# 1563/1563 [==============================] - 6s 4ms/step - loss: 0.6554 - accuracy: 0.7738 - val_loss: 0.7750 - val_accuracy: 0.7380
# Epoch 15/30
# 1563/1563 [==============================] - 6s 4ms/step - loss: 0.6470 - accuracy: 0.7779 - val_loss: 0.8088 - val_accuracy: 0.7284
# Epoch 16/30
# 1563/1563 [==============================] - 6s 4ms/step - loss: 0.6393 - accuracy: 0.7789 - val_loss: 0.8328 - val_accuracy: 0.7161
# Epoch 17/30
# 1563/1563 [==============================] - 6s 4ms/step - loss: 0.6322 - accuracy: 0.7816 - val_loss: 0.8279 - val_accuracy: 0.7285
# Epoch 18/30
# 1563/1563 [==============================] - 6s 4ms/step - loss: 0.6211 - accuracy: 0.7848 - val_loss: 0.8013 - val_accuracy: 0.7331
# Epoch 19/30
# 1563/1563 [==============================] - 6s 4ms/step - loss: 0.6203 - accuracy: 0.7846 - val_loss: 0.7833 - val_accuracy: 0.7407
# Epoch 20/30
# 1563/1563 [==============================] - 6s 4ms/step - loss: 0.6093 - accuracy: 0.7886 - val_loss: 0.7816 - val_accuracy: 0.7371
# Epoch 21/30
# 1563/1563 [==============================] - 6s 4ms/step - loss: 0.6044 - accuracy: 0.7898 - val_loss: 0.7872 - val_accuracy: 0.7367
# Epoch 22/30
# 1563/1563 [==============================] - 6s 4ms/step - loss: 0.5959 - accuracy: 0.7934 - val_loss: 0.8270 - val_accuracy: 0.7285
# Epoch 23/30
# 1563/1563 [==============================] - 6s 4ms/step - loss: 0.5954 - accuracy: 0.7940 - val_loss: 0.7613 - val_accuracy: 0.7518
# Epoch 24/30
# 1563/1563 [==============================] - 6s 4ms/step - loss: 0.5927 - accuracy: 0.7942 - val_loss: 0.7790 - val_accuracy: 0.7424
# Epoch 25/30
# 1563/1563 [==============================] - 6s 4ms/step - loss: 0.5857 - accuracy: 0.7972 - val_loss: 0.7921 - val_accuracy: 0.7441
# Epoch 26/30
# 1563/1563 [==============================] - 6s 4ms/step - loss: 0.5818 - accuracy: 0.7957 - val_loss: 0.7993 - val_accuracy: 0.7421
# Epoch 27/30
# 1563/1563 [==============================] - 6s 4ms/step - loss: 0.5729 - accuracy: 0.8005 - val_loss: 0.8082 - val_accuracy: 0.7355
# Epoch 28/30
# 1563/1563 [==============================] - 6s 4ms/step - loss: 0.5735 - accuracy: 0.8010 - val_loss: 0.8261 - val_accuracy: 0.7335
# Epoch 29/30
# 1563/1563 [==============================] - 6s 4ms/step - loss: 0.5720 - accuracy: 0.7990 - val_loss: 0.7769 - val_accuracy: 0.7468
# Epoch 30/30
# 1563/1563 [==============================] - 6s 4ms/step - loss: 0.5671 - accuracy: 0.8018 - val_loss: 0.7811 - val_accuracy: 0.7400

# %%
fig, ax = plt.subplots(figsize=(10,8))
fig.set_facecolor('lightgray')
plt.plot(history2.history['accuracy'], 'b')
plt.plot(history2.history['val_accuracy'], 'r')
plt.legend(['train acc', 'test acc'], fontsize=16)
ax.text(15, 0.765, 'Less\nOverfitting', fontsize=16,
        verticalalignment='top', bbox=dict(boxstyle='round', facecolor='wheat', alpha=0.5))
plt.xlabel('Epochs')
plt.grid(b=True)

# %%
prob_pred = model2.predict(x_test, batch_size=batch_size)
label_pred = np.argmax(prob_pred, axis=1)
plt.figure(figsize=(12,9))
plt.subplots_adjust(wspace=0.4, hspace=0.4)
for i in range(16):
    axes = plt.subplot(4,4,i+1)
    if label_pred[i]==t_test[i,0]:
        color = 'cyan'
    else:
        color = 'red'
    axes.set_title(class_names[label_pred[i]], fontdict={'fontsize':14, 'color':color})
    plt.imshow(xo_test[i])
